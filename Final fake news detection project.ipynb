# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import nltk
import re
import string 

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
ifind_data = pd.read_excel(r'C:\Users\pavithra\Desktop\IFND (1).xlsx')

# %%
ifind_data.head()
# Out:
#    id                                          Statement  \
# 0   2  WHO praises India's Aarogya Setu app, says it ...
# 1   3  In Delhi, Deputy US Secretary of State Stephen...
# 2   4  LAC tensions: China's strategy behind delibera...
# 3   5  India has signed 250 documents on Space cooper...
# 4   6  Tamil Nadu chief minister's mother passes away...
#
#                                                Image       Web  Category  \
# 0  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 1  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  VIOLENCE
# 2  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA    TERROR
# 3  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 4  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  ELECTION
#
#                   Date Label
# 0  2020-10-01 00:00:00  True
# 1  2020-10-01 00:00:00  True
# 2  2020-10-01 00:00:00  True
# 3  2020-10-01 00:00:00  True
# 4  2020-10-01 00:00:00  True

# %%
ifind_data['Label'].value_counts()
# Out:
# True    37800
# Fake    18914
# Name: Label, dtype: int64

# %%
ifind_data.rename(columns={'Statement': 'text', 'Label': 'target','Date':'date'}, inplace=True)

# %%
ifind_data['target'] = ifind_data['target'].astype(str)
ifind_data['target'].replace(['True','Fake'],[1,0], inplace=True)

# %%
ifind_data['target'].value_counts()
# Out:
# 1    37800
# 0    18914
# Name: target, dtype: int64

# %%
ifind_data.head()
# Out:
#    id                                               text  \
# 0   2  WHO praises India's Aarogya Setu app, says it ...
# 1   3  In Delhi, Deputy US Secretary of State Stephen...
# 2   4  LAC tensions: China's strategy behind delibera...
# 3   5  India has signed 250 documents on Space cooper...
# 4   6  Tamil Nadu chief minister's mother passes away...
#
#                                                Image       Web  Category  \
# 0  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 1  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  VIOLENCE
# 2  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA    TERROR
# 3  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  COVID-19
# 4  https://cdn.dnaindia.com/sites/default/files/s...  DNAINDIA  ELECTION
#
#                   date  target
# 0  2020-10-01 00:00:00       1
# 1  2020-10-01 00:00:00       1
# 2  2020-10-01 00:00:00       1
# 3  2020-10-01 00:00:00       1
# 4  2020-10-01 00:00:00       1

# %%
print(ifind_data["target"].value_counts())
g1 = plt.pie(ifind_data["target"].value_counts().values,explode=[0,0],labels=ifind_data.target.value_counts().index, autopct='%1.1f%%',colors=['SkyBlue','PeachPuff'])
plt.show()
# Out:
# 1    37800
# 0    18914
# Name: target, dtype: int64

# %%
print(ifind_data.Category.value_counts())
plt.figure(figsize=(10, 5))

ax = sns.countplot(x="Category",  hue='target', data=ifind_data, palette="pastel")
plt.title("Distribution of The Subject According to Real and Fake Data")
# Out:
# GOVERNMENT    10923
# VIOLENCE      10578
# COVID-19       8710
# POLITICS       8670
# ELECTION       8396
# TERROR         4384
# MISLEADING     4059
# TRAD            976
# MISLEADIND       18
# Name: Category, dtype: int64
# Text(0.5, 1.0, 'Distribution of The Subject According to Real and Fake Data')

# %%
print(ifind_data.Web.value_counts())
plt.figure(figsize=(30, 10))

ax = sns.countplot(x="Web",  hue='target', data=ifind_data, palette="pastel")
plt.title("Distribution of The Subject According to Real and Fake Data")
# Out:
# TRIBUNEINDIA        11832
# AUGMENT             11321
# THEPRINT             8582
# THESTATESMAN         7202
# THESTATEMAN          4048
# INDIANEXPRESS        3983
# NEWSMOBILE           2422
# INDIATODAY           1698
# BOOMLIVE              806
# CNN                   778
# NEWSMETER             572
# ONEINDIA              549
# BSMEDIA               449
# TEEKHIMIRCHI          387
# FACTCRESCENDO         272
# AFP                   267
# TIMESNOW              238
# THELOGICALINDIAN      221
# DIGITEYE              175
# FACTLY                174
# THELOGICALINDIA       173
# FACTCHECKER           163
# DAPAAN                136
# DNAINDIA              121
# ALT                    59
# WAHSARKAR              42
# ENGLISHTRIBUNE         21
# INDUSTANTIMES          15
# NDTV                    8
# Name: Web, dtype: int64
# Text(0.5, 1.0, 'Distribution of The Subject According to Real and Fake Data')

# %%
ifind_data.groupby(['Web','target'])['id'].count()
# Out:
# Web               target
# AFP               0           267
# ALT               0            59
# AUGMENT           0         11321
# BOOMLIVE          0           806
# BSMEDIA           1           449
# CNN               1           778
# DAPAAN            1           136
# DIGITEYE          0           175
# DNAINDIA          1           121
# ENGLISHTRIBUNE    1            21
# FACTCHECKER       0           163
# FACTCRESCENDO     0           272
# FACTLY            1           174
# INDIANEXPRESS     1          3983
# INDIATODAY        0          1606
#                   1            92
# INDUSTANTIMES     1            15
# NDTV              1             8
# NEWSMETER         0           506
#                   1            66
# NEWSMOBILE        0          2190
#                   1           232
# ONEINDIA          0           549
# TEEKHIMIRCHI      0           262
#                   1           125
# THELOGICALINDIA   0           173
# THELOGICALINDIAN  0           221
# THEPRINT          0           344
#                   1          8238
# THESTATEMAN       1          4048
# THESTATESMAN      1          7202
# TIMESNOW          1           238
# TRIBUNEINDIA      1         11832
# WAHSARKAR         1            42
# Name: id, dtype: int64

# %%
data = ifind_data[['text','target']].copy()

# %%
data.head()
# Out:
#                                                 text  target
# 0  WHO praises India's Aarogya Setu app, says it ...       1
# 1  In Delhi, Deputy US Secretary of State Stephen...       1
# 2  LAC tensions: China's strategy behind delibera...       1
# 3  India has signed 250 documents on Space cooper...       1
# 4  Tamil Nadu chief minister's mother passes away...       1

# %%
first_text = data.text[10]
first_text
# Out:
# "Amid stubble burning, Delhi's air quality deteriorates to 'very poor'"

# %%
#Removal of html content
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(first_text, "html.parser")
first_text = soup.get_text()
first_text
# Out:
# "Amid stubble burning, Delhi's air quality deteriorates to 'very poor'"

# %%
#removal of punctuation marks and special characters
first_text = re.sub('\[[^]]*\]', ' ', first_text)
first_text = re.sub('[^a-zA-Z]',' ',first_text)  # replaces non-alphabets with spaces
first_text = first_text.lower() # Converting from uppercase to lowercase
first_text
# Out:
# 'amid stubble burning  delhi s air quality deteriorates to  very poor '

# %%
 nltk.download('punkt')
 nltk.download("stopwords") 
 nltk.download('wordnet')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
#tokenization and stopwords
first_text = nltk.word_tokenize(first_text)
first_text = [ word for word in first_text if not word in set(stopwords.words("english"))]
first_text
# Out:
# ['amid',
#  'stubble',
#  'burning',
#  'delhi',
#  'air',
#  'quality',
#  'deteriorates',
#  'poor']

# %%
#lemmatization
import nltk
nltk.download('omw-1.4')
first_text = "Amid stubble burning, Delhi's air quality deteriorates to 'very poor "
lemma = nltk.WordNetLemmatizer()
first_text = [ lemma.lemmatize(word) for word in first_text.split()] 
first_text = " ".join(first_text)
first_text
# Out:
# [nltk_data] Error loading omw-1.4: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# "Amid stubble burning, Delhi's air quality deteriorates to 'very poor"

# %%
#Removal of HTML Contents
def remove_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removal of Punctuation Marks
def remove_punctuations(text):
    return re.sub('\[[^]]*\]', '', text)

# Removal of Special Characters
def remove_characters(text):
    return re.sub("[^a-zA-Z]"," ",text)

# %%
#Removal of stopwords 
def remove_stopwords_and_lemmatization(text):
    final_text = []
    text = text.lower()
    text = nltk.word_tokenize(text)
    #lemma = nltk.WordNetLemmatizer()
    
    final_text = [word for word in text if word not in stopwords.words('english')]
    return " ".join(final_text)

# %%
def remove_stopwords(text):
    final_text = []
    final_text = [word for word in text.split() if word.lower() not in stopwords.words('english')]
    return " ".join(final_text)

# %%
#Total function
def cleaning(text):
    text = remove_html(text)
    text = remove_punctuations(text)
    text = remove_characters(text)
    text = remove_stopwords_and_lemmatization(text)
    return text

# %%
data['text']=data['text'].apply(remove_html)
data['text']=data['text'].apply(remove_punctuations)
data['text']=data['text'].apply(remove_characters)
data['text']=data['text'].apply(remove_stopwords)

# %%
data.head()
# Out:
#                                                 text  target
# 0  praises India Aarogya Setu app says helped ide...       1
# 1  Delhi Deputy US Secretary State Stephen Biegun...       1
# 2  LAC tensions China strategy behind deliberatel...       1
# 3  India signed documents Space cooperation count...       1
# 4       Tamil Nadu chief minister mother passes away       1

# %%
data.tail()
# Out:
#                                                     text  target
# 56709    Fact Check Bruce Lee playing ping pong Nunchaku       0
# 56710            Fact Check Japan construct bridge hours       0
# 56711  Fact Check Viral video Mexico earthquake years...       0
# 56712  Fact Check Ballet performance Chinese couple g...       0
# 56713  Fact Check little boy crossing Jordan alone lo...       0

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\pavithra\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\pavithra\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in c:\users\pavithra\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\pavithra\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pavithra\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\pavithra\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pavithra\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\pavithra\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\pavithra\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pavithra\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pavithra\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pavithra\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud,STOPWORDS
plt.figure(figsize = (15,15))
wc = WordCloud(max_words = 500 , width = 1000 , height = 500 , stopwords = STOPWORDS).generate(" ".join(data[data.target == 1].text))
plt.imshow(wc , interpolation = 'bilinear')

# %%
plt.figure(figsize = (15,15))
wc = WordCloud(max_words = 500 , width = 1000 , height = 500 , stopwords = STOPWORDS).generate(" ".join(data[data.target == 0].text))
plt.imshow(wc , interpolation = 'bilinear')

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,8))
text_len=data[data['target']==0]['text'].str.split().map(lambda x: len(x))
ax1.hist(text_len,color='SkyBlue')
ax1.set_title('Fake news text')
text_len=data[data['target']==1]['text'].str.split().map(lambda x: len(x))
ax2.hist(text_len,color='PeachPuff')
ax2.set_title('Real news text')
fig.suptitle('Words in texts')
plt.show()

# %%
texts = ' '.join(data['text'])

# %%
string = texts.split(" ")

# %%
def draw_n_gram(string,i):
    n_gram = (pd.Series(nltk.ngrams(string, i)).value_counts())[:15]
    n_gram_df=pd.DataFrame(n_gram)
    n_gram_df = n_gram_df.reset_index()
    n_gram_df = n_gram_df.rename(columns={"index": "word", 0: "count"})
    print(n_gram_df.head())
    plt.figure(figsize = (16,9))
    return sns.barplot(x='count',y='word', data=n_gram_df)

# %%
draw_n_gram(string,1)
# Out:
#        word  count
# 0   (Fact,)   9958
# 1  (Check,)   9045
# 2  (India,)   5122
# 3    (BJP,)   4680
# 4   (Modi,)   4518
# <Axes: xlabel='count', ylabel='word'>

# %%
draw_n_gram(string,2)
# Out:
#               word  count
# 0    (Fact, Check)   9011
# 1       (PM, Modi)   2328
# 2  (Rahul, Gandhi)   1228
# 3     (Amit, Shah)    739
# 4           (J, K)    711
# <Axes: xlabel='count', ylabel='word'>

# %%
draw_n_gram(string,3)
# Out:
#                        word  count
# 0        (Fact, Check, Old)    638
# 1      (Fact, Check, Viral)    429
# 2      (Fact, Check, Video)    373
# 3  (Sushant, Singh, Rajput)    189
# 4      (Fact, Check, video)    176
# <Axes: xlabel='count', ylabel='word'>

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X = data['text']
y = data['target']
td = TfidfVectorizer(max_features = 4500)
X = td.fit_transform(X).toarray()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
print('\n the total number of training data :',y_train.shape)
# Out:
#  the total number of training data : (39699,)

# %%
print('\n the total number of testing data :',y_test.shape)
# Out:
#  the total number of testing data : (17015,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_lr = LogisticRegression()
classifier_lr.fit(X_train, y_train)
y_pred = classifier_lr.predict(X_test)
# Classification metrics
classification_report = classification_report(y_test, y_pred)
print('\n Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
#  Accuracy:  0.9342344989714957

# %%
# Training the classifier & predicting on test data
classifier_nb = MultinomialNB()
classifier_nb.fit(X_train, y_train)
y_pred = classifier_nb.predict(X_test)
# Classification metrics

print('\n Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
#  Accuracy:  0.9286511901263591

# %%
classifier_rf = RandomForestClassifier(n_estimators=10)
classifier_rf.fit(X_train, y_train)
y_pred = classifier_rf.predict(X_test)
print('\n Accuracy: ', accuracy_score(y_test, y_pred))
# Out:
#  Accuracy:  0.9330590655304143

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\pavithra\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\pavithra\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: click in c:\users\pavithra\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: joblib in c:\users\pavithra\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pavithra\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\pavithra\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: colorama in c:\users\pavithra\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)

# %%
import requests
import nltk
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
from textblob import TextBlob
from datetime import datetime

# %%
def timesofindia():
    url = "https://timesofindia.indiatimes.com/home/headlines"
    page_request = requests.get(url)
    data = page_request.content
    soup = BeautifulSoup(data,"html.parser")
    times_of_india_news = []
    counter = 0
    for divtag in soup.find_all('div', {'class': 'headlines-list'}):
        for ultag in divtag.find_all('ul', {'class': 'clearfix'}):
            if (counter <= 10):
                for litag in ultag.find_all('li'):
                    counter = counter + 1
                    print(str(counter),datetime.today().strftime('%Y-%m-%d') + "." + litag.text + " - https://timesofindia.indiatimes.com" + litag.find('a')['href'])
                    times_of_india_news.append(['Times of India',datetime.today().strftime('%Y-%m-%d'),litag.text])
    return times_of_india_news

# %%
times_of_india_news = timesofindia()
# Out:
# 1 2023-05-29.New Parliament a symbol of confident, 21st century India28 May 2023, 2114 hrs IST - https://timesofindia.indiatimes.com/india/new-parliament-a-symbol-of-confident-21st-century-india/articleshow/100573185.cms
# 2 2023-05-29.70yrs on, Norgay & Hillary sons unite to celebrate Himalayan feat - https://timesofindia.indiatimes.com/india/70-years-on-norgay-hillary-sons-unite-to-celebrate-himalayan-feat/articleshow/100575497.cms
# 3 2023-05-29.95,000-plus UPI frauds: 9 things that make users lose money on apps - https://timesofindia.indiatimes.comhttps://www.gadgetsnow.com/slideshows/95000-plus-upi-frauds-9-things-that-make-users-lose-money-on-googlepay-paytm-phonepe-and-other-financial-apps/photolist/100579126.cms
# 4 2023-05-29.IPL final, weather updates: Better forecast for Monday - https://timesofindia.indiatimes.com/sports/cricket/ipl/top-stories/weather-updates-gt-vs-csk-better-forecast-for-ipl-final-on-reserve-day-may-29/articleshow/100579499.cms
# 5 2023-05-29.IT company Airmeet lays off 30% of workforce; CEO's mail to employees cites reasons - https://timesofindia.indiatimes.comhttps://www.gadgetsnow.com/tech-news/it-company-airmeet-lays-off-30-of-workforce-reasons-that-ceos-email-to-employees-gives-for-job-cuts/articleshow/100579706.cms
# 6 2023-05-29.Top10: How cost overruns and delays impact infrastructure projects - https://timesofindia.indiatimes.comhttps://m.timesofindia.com/apptimestopten
# 7 2023-05-29.ChatGPT 'fools' lawyer who now faces sanctions - https://timesofindia.indiatimes.comhttps://www.gadgetsnow.com/tech-news/chatgpt-fools-lawyer-who-now-faces-sanctions/articleshow/100580010.cms
# 8 2023-05-29.Live: Isro begins countdown for launch of navigation satellite - https://timesofindia.indiatimes.com/india/isro-gslv-launch-live-updates-indian-navic-satellite-gslv-f12-nvs1-mission-launch/liveblog/100578730.cms
# 9 2023-05-29.Bengal flirts with fire, blasts at illegal cracker units claim lives - https://timesofindia.indiatimes.com/city/kolkata/bengal-flirts-with-fire-blasts-at-illegal-cracker-units-claim-lives/articleshow/100575459.cms
# 10 2023-05-29.Conversion racket busted, 18 held, claim UP police - https://timesofindia.indiatimes.com/city/varanasi/conversion-racket-busted-18-held-claim-up-police/articleshow/100575524.cms
# 11 2023-05-29.Fundamental right: Woman allowed to abort 23-week fetus - https://timesofindia.indiatimes.com/city/mumbai/fundamental-right-woman-allowed-to-abort-23-week-fetus/articleshow/100575269.cms
# 12 2023-05-29.Residents of villages near Kuno hold prayers for safety of cheetahs - https://timesofindia.indiatimes.com/videos/toi-original/watch-residents-of-villages-near-kuno-national-park-hold-prayers-and-conduct-havan-for-safety-of-cheetahs/videoshow/100574433.cms

# %%
pip install -U pip
# Out:
# Requirement already satisfied: pip in c:\users\pavithra\anaconda3\lib\site-packages (23.1.2)Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade setuptools
# Out:
# Requirement already satisfied: setuptools in c:\users\pavithra\anaconda3\lib\site-packages (67.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install feedparser
# Out:
# Requirement already satisfied: feedparser in c:\users\pavithra\anaconda3\lib\site-packages (6.0.8)
# Requirement already satisfied: sgmllib3k in c:\users\pavithra\anaconda3\lib\site-packages (from feedparser) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "beautifulsoup4==4.9.1"
# Out:
# Requirement already satisfied: beautifulsoup4==4.9.1 in c:\users\pavithra\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\pavithra\anaconda3\lib\site-packages (from beautifulsoup4==4.9.1) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "dateparser==0.7.6"
# Out:
# Requirement already satisfied: dateparser==0.7.6 in c:\users\pavithra\anaconda3\lib\site-packages (0.7.6)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: python-dateutil in c:\users\pavithra\anaconda3\lib\site-packages (from dateparser==0.7.6) (2.8.2)
# Requirement already satisfied: pytz in c:\users\pavithra\anaconda3\lib\site-packages (from dateparser==0.7.6) (2022.7)
# Requirement already satisfied: regex!=2019.02.19 in c:\users\pavithra\anaconda3\lib\site-packages (from dateparser==0.7.6) (2022.7.9)
# Requirement already satisfied: tzlocal in c:\users\pavithra\anaconda3\lib\site-packages (from dateparser==0.7.6) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\pavithra\anaconda3\lib\site-packages (from python-dateutil->dateparser==0.7.6) (1.16.0)
# Requirement already satisfied: tzdata in c:\users\pavithra\anaconda3\lib\site-packages (from tzlocal->dateparser==0.7.6) (2023.3)

# %%
pip install "requests==2.24.0"
# Out:
# Requirement already satisfied: requests==2.24.0 in c:\users\pavithra\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\pavithra\anaconda3\lib\site-packages (from requests==2.24.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pavithra\anaconda3\lib\site-packages (from requests==2.24.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pavithra\anaconda3\lib\site-packages (from requests==2.24.0) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pavithra\anaconda3\lib\site-packages (from requests==2.24.0) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "feedparser==6.0.8"
# Out:
# Requirement already satisfied: feedparser==6.0.8 in c:\users\pavithra\anaconda3\lib\site-packages (6.0.8)
# Requirement already satisfied: sgmllib3k in c:\users\pavithra\anaconda3\lib\site-packages (from feedparser==6.0.8) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --no-deps pygooglenews
# Out:
# Requirement already satisfied: pygooglenews in c:\users\pavithra\anaconda3\lib\site-packages (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pygooglenews import GoogleNews
import json
import time



def fetching_google_news():
    gn = GoogleNews()
    top = gn.top_news()

    entries = top["entries"]
    count = 0
    google_news = []
    for entry in entries:
        count = count + 1
        print( str(count) + ". " + entry["title"] + entry["published"])
        google_news.append(['Google News',entry["published"],entry["title"] ])
        time.sleep(0.25)
    return google_news

# %%
google_news = fetching_google_news()
# Out:
# 1. Biden urges Congress to pass debt ceiling deal - ABC NewsMon, 29 May 2023 00:00:00 GMT
# 2. Erdogan wins Turkish election, extending rule to third decade - CNNMon, 29 May 2023 02:15:00 GMT
# 3. Trump criticizes Texas Gov. Abbott for silence on impeachment of AG Ken Paxton - The HillSun, 28 May 2023 22:13:00 GMT
# 4. Man charged with murder after 3 dead in New Mexico biker shootout - ReutersSun, 28 May 2023 19:57:00 GMT
# 5. Escaped inmate from northwest Ohio prison found dead in Ohio River - WBNS 10TVSun, 28 May 2023 22:51:41 GMT
# 6. PBS News Weekend full episode, May 28, 2023 - PBS NewsHourSun, 28 May 2023 21:56:12 GMT
# 7. Joe Biden On Why He Negotiated With Republicans On Budget And Debt Ceiling Deal: “Can You Think Of An Alternative?” — Update - DeadlineSun, 28 May 2023 22:47:00 GMT
# 8. Arizona man arrested after police connect him to shooting spree that left 4 dead, 1 injured - Fox NewsMon, 29 May 2023 01:06:00 GMT
# 9. 'My fellow Republicans wanted me to lie,' Liz Cheney says in commencement speech - POLITICOSun, 28 May 2023 21:10:48 GMT
# 10. Texas Republicans pass voting bills targeting large Democratic county - The Washington PostMon, 29 May 2023 02:37:55 GMT
# 11. Russia unleashes largest drone attack on Ukrainian capital, crowds mark Kyiv Day - ReutersMon, 29 May 2023 01:06:00 GMT
# 12. Putin Ally Offers Nuclear Weapons to Anyone Willing to Join Russia - NewsweekSun, 28 May 2023 20:25:02 GMT
# 13. North Korea plans ‘satellite’ launch in next two weeks: Japan - Al Jazeera EnglishMon, 29 May 2023 01:05:37 GMT
# 14. Spain's conservative PP elbows Socialists out in regional elections - ReutersSun, 28 May 2023 23:04:00 GMT
# 15. Asia markets rise after U.S. reaches debt ceiling deal, Japan stocks at highest since July 1990 - CNBCMon, 29 May 2023 03:06:00 GMT
# 16. Ford’s Deal To Use Tesla Charging Connector And Superchargers Could Kill CCS - ForbesSun, 28 May 2023 16:36:13 GMT
# 17. Singapore's Temasek cuts compensation for staff responsible for FTX investment - ReutersMon, 29 May 2023 00:18:00 GMT
# 18. Companies and individuals without AI expertise will be left behind: tech CEO - The HillSun, 28 May 2023 23:51:00 GMT
# 19. Here's Which Streaming Platforms The Sonos Era 300 & 100 Support For Spatial Audio - SlashGearSun, 28 May 2023 01:00:00 GMT
# 20. AirPlay upgrade part of expected inbound iOS 17 changes - AppleInsiderSun, 28 May 2023 15:05:54 GMT
# 21. Tekken 8's latest character reveal was posted too early, upsetting director Harada – VGC - Video Games ChronicleSun, 28 May 2023 20:24:11 GMT
# 22. Quordle today - hints and answers for Sunday, May 28 (game #489) - TechRadarSun, 28 May 2023 08:13:55 GMT
# 23. ‘Succession’ Series Finale: The Roy Family Saga Ended in a Breathtaking Blindside - Hollywood ReporterMon, 29 May 2023 02:39:39 GMT
# 24. Indy 500 fans SLAM Jewel for 'extremely disrespectful' national anthem - Daily MailSun, 28 May 2023 22:37:48 GMT
# 25. 'The Little Mermaid' makes box office splash with $95.5 million opening - The Associated PressSun, 28 May 2023 23:45:34 GMT
# 26. Billie Eilish Slams Haters Of Her Style Evolution - DeadlineSun, 28 May 2023 20:46:00 GMT
# 27. Celtics vs. Heat: NBA explains controversial calls at the end of Game 6 in Last Two Minute Report - CBS SportsMon, 29 May 2023 00:32:00 GMT
# 28. Raiders could get out of Jimmy Garoppolo contract if foot injury lingers - New York PostSun, 28 May 2023 21:16:24 GMT
# 29. Did Fernando Alonso and Aston Martin throw away a Monaco win? - ESPN - ESPNSun, 28 May 2023 19:30:00 GMT
# 30. Miami Heat fall to Celtics 104-103 on buzzer-beater, forcing Game 7 in Boston - CBS NewsSun, 28 May 2023 20:25:00 GMT
# 31. NASA's dazzling photo hides a secret - MashableSat, 27 May 2023 09:30:00 GMT
# 32. Rare images reveal sunspots larger than Earth - CNNSun, 28 May 2023 18:58:14 GMT
# 33. Amish families have figured out an ingenious way to dry clothes without household appliances in the winter — here's how they do it - msnNOWMon, 29 May 2023 02:00:00 GMT
# 34. Scientists Find Way to Make Energy from Air Using Nearly Any Material - SlashdotSat, 27 May 2023 19:50:29 GMT
# 35. Scientists use AI to discover antibiotic to fight deadly hospital bug - USA TODAYMon, 29 May 2023 03:02:35 GMT
# 36. Top 5 Neuroscience News Stories of the Week - Neuroscience NewsSun, 28 May 2023 21:24:02 GMT
# 37. Ultrasound Induces Torpor-Like State in Animals, Experiment Shows - ScienceAlertMon, 29 May 2023 00:50:16 GMT
# 38. Slowing Cognitive Aging: Major Study Finds Daily Multivitamin Improves Memory in Older Adults - SciTechDailySun, 28 May 2023 11:05:55 GMT

# %%
news_content = []

# %%
news_content+=times_of_india_news
news_content+= google_news
news_content_df = pd.DataFrame(news_content,columns = ['New_Site','Date' , 'Title'])

# %%
news_content_df.head()
# Out:
#          New_Site        Date  \
# 0  Times of India  2023-05-29
# 1  Times of India  2023-05-29
# 2  Times of India  2023-05-29
# 3  Times of India  2023-05-29
# 4  Times of India  2023-05-29
#
#                                                Title
# 0  New Parliament a symbol of confident, 21st cen...
# 1  70yrs on, Norgay & Hillary sons unite to celeb...
# 2  95,000-plus UPI frauds: 9 things that make use...
# 3  IPL final, weather updates: Better forecast fo...
# 4  IT company Airmeet lays off 30% of workforce; ...

# %%
textblob_sentiment=[]
for index , row in news_content_df.iterrows():
    title = row['Title']
    txt= TextBlob(title)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([a,b])

# %%
news_content_df['Text_blob_Polarity'] , news_content_df['Text_blob_Subjectivity'] = zip(*textblob_sentiment)

# %%
news_content_df['Title_clean']=news_content_df['Title'].apply(remove_html)
news_content_df['Title_clean']=news_content_df['Title_clean'].apply(remove_punctuations)
news_content_df['Title_clean']=news_content_df['Title_clean'].apply(remove_characters)
news_content_df['Title_clean']=news_content_df['Title_clean'].apply(remove_stopwords)

# %%
X_real = td.transform(news_content_df['Title_clean']).toarray()

# %%
news_content_df['Prediction_LR'] = classifier_lr.predict(X_real)
news_content_df['Prediction_RF'] = classifier_rf.predict(X_real)
news_content_df['Prediction_NB'] = classifier_nb.predict(X_real)

# %%
news_content_df['Prediction_LR'].replace([1,0], ['True','Fake'],inplace=True)
news_content_df['Prediction_RF'].replace([1,0], ['True','Fake'],inplace=True)
news_content_df['Prediction_NB'].replace([1,0], ['True','Fake'],inplace=True)

# %%
news_content_df.head()
# Out:
#          New_Site        Date  \
# 0  Times of India  2023-05-29
# 1  Times of India  2023-05-29
# 2  Times of India  2023-05-29
# 3  Times of India  2023-05-29
# 4  Times of India  2023-05-29
#
#                                                Title  Text_blob_Polarity  \
# 0  New Parliament a symbol of confident, 21st cen...            0.212121
# 1  70yrs on, Norgay & Hillary sons unite to celeb...            0.000000
# 2  95,000-plus UPI frauds: 9 things that make use...            0.000000
# 3  IPL final, weather updates: Better forecast fo...            0.250000
# 4  IT company Airmeet lays off 30% of workforce; ...            0.000000
#
#    Text_blob_Subjectivity                                        Title_clean  \
# 0                0.429293  New Parliament symbol confident st century Ind...
# 1                0.000000  yrs Norgay Hillary sons unite celebrate Himala...
# 2                0.000000  plus UPI frauds things make users lose money apps
# 3                0.750000   IPL final weather updates Better forecast Monday
# 4                0.000000  company Airmeet lays workforce CEO mail employ...
#
#   Prediction_LR Prediction_RF Prediction_NB
# 0          True          True          True
# 1          True          True          True
# 2          True          True          True
# 3          True          True          True
# 4          True          True          True

# %%
news_content_df.to_excel('Result.xlsx')

# %%
def real_time_prediction(news):
  news_transformed = td.transform([news]).toarray()
  Prediction_LR = classifier_lr.predict(news_transformed)
  Prediction_RF = classifier_rf.predict(news_transformed)
  Prediction_NB = classifier_nb.predict(news_transformed)
  Prediction_LR = ['Real'  if i == 1 else 'Fake' for i in Prediction_LR ]
  print(f"Based on Logistic Regression model this News is ::{Prediction_LR[0]}")
  Prediction_RF = ['Real'  if i == 1 else 'Fake' for i in Prediction_RF ]
  print(f"Based on  Random Forest Model this News is ::{Prediction_RF[0]}")
  Prediction_NB = ['Real'  if i == 1 else 'Fake' for i in Prediction_NB ]
  print(f"Based on Naive Bayes model this News is :: {Prediction_NB[0]} ")

# %%
news = input("Please Enter the News which you want to predict : ")
real_time_prediction(news)
